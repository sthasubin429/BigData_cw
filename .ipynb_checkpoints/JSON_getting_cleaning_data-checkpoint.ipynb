# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.ny.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.ny.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of


# dictionaries by sodapy.
# results = client.get("bui8-bb6g", limit=2000)

# Convert to pandas DataFrame
# results_df = pd.DataFrame.from_records(results)

# %%
import pandas as pd
from sodapy import Socrata

# %%
api_key_id = "a64z6l0t6lqj6xlzsv9eebdot"
api_key_secret = "3b81rccnr5qie79sl2b4v0pzr143yx9qvuodc7xwye63aki7bp"
app_token = "OTLywsj7FC4hrQovFJtIH2W3S"
app_secret_token = "k0HPFFty7qaJNP_KeWAOLdZS82TuKcWXnZ6y"

# %%
client = Socrata("data.ny.gov",
                 app_token,
                 username="subinshrestha922@gmail.com",
                 password="zhk7KQK#rHsBL6yy")

# %%
results = client.get_all("bui8-bb6g")
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#        county_county_group households_with_elderly households_with_children  \
# 0                   Queens                     Yes                       No
# 1                   Queens                      No                      Yes
# 2                     Erie                     Yes                       No
# 3                   Queens                      No                       No
# 4                     Erie                     Yes                       No
# ...                    ...                     ...                      ...
# 223080            New York                      No                       No
# 223081            New York                      No                       No
# 223082              Queens                     Yes                      Yes
# 223083            New York                      No                       No
# 223084             Niagara                      No                       No
#
#        economic_development_region     income_groups  \
# ...

# %%
sample1 = results_df.sample(frac=0.03, random_state=2039281)

# %%
sample1
# Out:
#                         county_county_group households_with_elderly  \
# 218288                           Chautauqua                     Yes
# 1475                                 Monroe                      No
# 83036                                Nassau                     Yes
# 97205           Steuben, Schuyler & Chemung                     Yes
# 142923                             Saratoga                      No
# ...                                     ...                     ...
# 56104   Clinton, Franklin, Essex & Hamilton                     Yes
# 210504                             Dutchess                      No
# 65339                                 Bronx                      No
# 1088                               New York                      No
# 117384                               Orange                      No
#
#        households_with_children economic_development_region     income_groups  \
# ...

# %%
sample1["county_county_group"].unique()
# Out:
# array(['Chautauqua', 'Monroe', 'Nassau', 'Steuben, Schuyler & Chemung',
#        'Saratoga', 'Queens', 'Kings', 'Warren & Washington', 'Bronx',
#        'Erie', 'Orange', 'Cayuga & Onondaga', 'Rockland', 'Westchester',
#        'Oswego', 'Genesee & Orleans', 'Suffolk', 'Jefferson & Lewis',
#        'Albany', 'Rensselaer', 'Sullivan & Ulster',
#        'Cattaraugus & Allegany', 'Dutchess',
#        'Clinton, Franklin, Essex & Hamilton', 'St. Lawrence', 'Tompkins',
#        'Ontario & Yates', 'Otsego, Schoharie, Oneida, & Herkimer',
#        'Columbia & Greene', 'Putnam', 'Wayne & Seneca', 'Schenectady',
#        'Livingston & Wyoming', 'New York', 'Richmond', 'Niagara',
#        'Fulton & Montgomery', 'Broome, Chenango, Delaware, & Tioga',
#        'Madison & Cortland'], dtype=object)

# %%
results_df["county_county_group"].unique()
# Out:
# array(['Queens', 'Erie', 'New York', 'Kings', 'Niagara',
#        'Otsego, Schoharie, Oneida, & Herkimer', 'Cayuga & Onondaga',
#        'Dutchess', 'Nassau', 'Madison & Cortland',
#        'Broome, Chenango, Delaware, & Tioga', 'Bronx', 'Rensselaer',
#        'Suffolk', 'Columbia & Greene', 'Chautauqua', 'Tompkins',
#        'Clinton, Franklin, Essex & Hamilton', 'Monroe',
#        'Steuben, Schuyler & Chemung', 'Cattaraugus & Allegany',
#        'Rockland', 'Ontario & Yates', 'Westchester', 'St. Lawrence',
#        'Warren & Washington', 'Orange', 'Livingston & Wyoming',
#        'Genesee & Orleans', 'Sullivan & Ulster', 'Fulton & Montgomery',
#        'Schenectady', 'Jefferson & Lewis', 'Richmond', 'Wayne & Seneca',
#        'Albany', 'Saratoga', 'Oswego', 'Putnam'], dtype=object)

# %%
county_list = results_df["county_county_group"].unique()

# %%
county_list
# Out:
# array(['Queens', 'Erie', 'New York', 'Kings', 'Niagara',
#        'Otsego, Schoharie, Oneida, & Herkimer', 'Cayuga & Onondaga',
#        'Dutchess', 'Nassau', 'Madison & Cortland',
#        'Broome, Chenango, Delaware, & Tioga', 'Bronx', 'Rensselaer',
#        'Suffolk', 'Columbia & Greene', 'Chautauqua', 'Tompkins',
#        'Clinton, Franklin, Essex & Hamilton', 'Monroe',
#        'Steuben, Schuyler & Chemung', 'Cattaraugus & Allegany',
#        'Rockland', 'Ontario & Yates', 'Westchester', 'St. Lawrence',
#        'Warren & Washington', 'Orange', 'Livingston & Wyoming',
#        'Genesee & Orleans', 'Sullivan & Ulster', 'Fulton & Montgomery',
#        'Schenectady', 'Jefferson & Lewis', 'Richmond', 'Wayne & Seneca',
#        'Albany', 'Saratoga', 'Oswego', 'Putnam'], dtype=object)

# %%
sample1
# Out:
#                         county_county_group households_with_elderly  \
# 218288                           Chautauqua                     Yes
# 1475                                 Monroe                      No
# 83036                                Nassau                     Yes
# 97205           Steuben, Schuyler & Chemung                     Yes
# 142923                             Saratoga                      No
# ...                                     ...                     ...
# 56104   Clinton, Franklin, Essex & Hamilton                     Yes
# 210504                             Dutchess                      No
# 65339                                 Bronx                      No
# 1088                               New York                      No
# 117384                               Orange                      No
#
#        households_with_children economic_development_region     income_groups  \
# ...

# %%
sample = results_df.sample(n=0, random_state=2039281)
for county in county_list :
    temp_df = results_df[results_df["county_county_group"] == county]
    temp_sample = temp_df.sample(frac=0.03, random_state=2039281)
    sample = sample.append(temp_sample, ignore_index=True)

# %%
sample
# Out:
#      county_county_group households_with_elderly households_with_children  \
# 0                 Queens                     Yes                       No
# 1                 Queens                     Yes                       No
# 2                 Queens                     Yes                       No
# 3                 Queens                      No                       No
# 4                 Queens                      No                       No
# ...                  ...                     ...                      ...
# 6687              Putnam                      No                       No
# 6688              Putnam                     Yes                       No
# 6689              Putnam                      No                      Yes
# 6690              Putnam                     Yes                       No
# 6691              Putnam                      No                      Yes
#
#      economic_development_region     income_groups  \
# ...

# %%
id = [str(i) for i in range(0,len(sample))]
sample.insert(0, '_id', id)
sample
# Out:
#        _id county_county_group households_with_elderly  \
# 0        0              Queens                     Yes
# 1        1              Queens                     Yes
# 2        2              Queens                     Yes
# 3        3              Queens                      No
# 4        4              Queens                      No
# ...    ...                 ...                     ...
# 6687  6687              Putnam                      No
# 6688  6688              Putnam                     Yes
# 6689  6689              Putnam                      No
# 6690  6690              Putnam                     Yes
# 6691  6691              Putnam                      No
#
#      households_with_children economic_development_region     income_groups  \
# 0                          No               New York City          $50,000+
# 1                          No               New York City  $30,000-<$40,000
# ...

# %%
sample.drop(columns=['non_elderly_disabled_indicator','main_heating_fuel_type', 
                     'home_energy_payment_method', 'housing_vintage', 'time_in_home', 
                     'household_type', 'housing_unit_type' , 'linguistic_isolation'], inplace =True)

# %%
sample.rename(columns = {'county_county_group':'county', 
                         'economic_development_region':'development_region',
                         'percent_of_poverty_level':'poverty_level',
                        'race_ethnicity':'ethnicity', 
                        'owner_renter_status':'house_status', 
                        'lmi_study_region':'study_region',
                        'lmi_population_segment':'population_segment',
                        'income_groups':'income',
                        'low_to_moderate_income_group':'income_groups'}, inplace = True)

# %%
sample
# Out:
#        _id  county households_with_elderly households_with_children  \
# 0        0  Queens                     Yes                       No
# 1        1  Queens                     Yes                       No
# 2        2  Queens                     Yes                       No
# 3        3  Queens                      No                       No
# 4        4  Queens                      No                       No
# ...    ...     ...                     ...                      ...
# 6687  6687  Putnam                      No                       No
# 6688  6688  Putnam                     Yes                       No
# 6689  6689  Putnam                      No                      Yes
# 6690  6690  Putnam                     Yes                       No
# 6691  6691  Putnam                      No                      Yes
#
#      development_region            income                  poverty_level  \
# 0         New York City          $50,000+  4 - Income 201% HHSPG or more
# ...

# %%
sample.describe()
# Out:
#          _id county households_with_elderly households_with_children  \
# count   6692   6692                    6692                     6692
# unique  6692     39                       2                        2
# top      182  Kings                      No                       No
# freq       1    823                    3810                     4774
#
#        development_region    income                  poverty_level  \
# count                6692      6692                           6692
# unique                 10         6                              4
# top         New York City  $50,000+  4 - Income 201% HHSPG or more
# freq                 2390      3962                           4840
#
#             income_groups            ethnicity house_status study_region  \
# count                6692                 6692         6692         6692
# unique                  4                    5            2            7
# ...

# %%
# sample.to_json(r'income_NY_sample.json', orient='records')

# %%
sample
# Out:
#        _id  county households_with_elderly households_with_children  \
# 0        0  Queens                     Yes                       No
# 1        1  Queens                     Yes                       No
# 2        2  Queens                     Yes                       No
# 3        3  Queens                      No                       No
# 4        4  Queens                      No                       No
# ...    ...     ...                     ...                      ...
# 6687  6687  Putnam                      No                       No
# 6688  6688  Putnam                     Yes                       No
# 6689  6689  Putnam                      No                      Yes
# 6690  6690  Putnam                     Yes                       No
# 6691  6691  Putnam                      No                      Yes
#
#      development_region            income                  poverty_level  \
# 0         New York City          $50,000+  4 - Income 201% HHSPG or more
# ...
